# %%
import torch
from torch import nn
from torchinfo import summary
from torch.optim.lr_scheduler import CosineAnnealingLR
import torch.nn.functional as F
import matplotlib.pyplot as plt

from going_modular.custom_data_setup_main_train import LoadDataset
from going_modular import engine, utils
from going_modular import custom_data_setup_main_train
from going_modular.OneHeadModel import OneHeadModel

import helper_functions
# Out:
# c:\Users\Amiroodi\AppData\Local\Programs\Python\Python311\Lib\site-packages\albumentations\__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.5'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# c:\Users\Amiroodi\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\amp\grad_scaler.py:132: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(

# %%
allow_train = True
load_pre_train_model = False
freeze_encoder = False
EPOCHS = 15
BATCH_SIZE = 32
shrink_size = 400

lr = 0.00005
weight_deacay = 0
# T_max = 70
# eta_min = 1e-7
num_augs = 3
p_dropout = 0.5

crop_size = 224

# weights for alpha is inverse frequency

# alpha = torch.tensor([1/1805, 1/370, 1/999, 1/193, 1/295]) * 500 
# alpha = torch.tensor([1, 1, 1, 1, 1])
# gamma = 2
# label_smoothing = 0.1

# alpha = [1] * 5
# alpha = [1/1805, 1/370, 1/999, 1/193, 1/295] * 500

# %%
# Set matmul precision for TF32 usage on Ampere+ GPUs
# torch.set_float32_matmul_precision('medium')

# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %% [markdown]
# Augmentation

# %%
train_transforms = helper_functions.get_augmentation_train_transforms(num_augs, crop_size)
test_transforms = helper_functions.get_augmentation_test_transforms(crop_size)
no_transforms = helper_functions.get_augmentation_no_transforms(crop_size)

# %%
# load all dataloaders

train_dataloader, val_dataloader, class_names = custom_data_setup_main_train.create_train_val_dataloader(
    batch_size=BATCH_SIZE,
    train_transform=train_transforms,
    val_transform=test_transforms,
    shrink_size=shrink_size)

test_dataloader, class_names = custom_data_setup_main_train.create_test_dataloader(
    batch_size=BATCH_SIZE,
    test_transform=test_transforms, 
    shrink_size=shrink_size) 

exp_train_dataloader, class_names = custom_data_setup_main_train.create_train_dataloader(
    batch_size=BATCH_SIZE,
    train_transform=test_transforms,
    shrink_size=shrink_size)

MESSIDOR_dataloader, class_name = custom_data_setup_main_train.create_exotic_test_dataloader(
    batch_size=BATCH_SIZE,
    test_transform=test_transforms,
    dataset_name='MESSIDOR',
    shrink_size=shrink_size)   

IDRID_dataloader, class_name = custom_data_setup_main_train.create_exotic_test_dataloader(
    batch_size=BATCH_SIZE,
    test_transform=test_transforms,
    dataset_name='IDRID',
    shrink_size=shrink_size) 

APTOS_15_test_dataloader, class_name = custom_data_setup_main_train.create_exotic_test_dataloader(
    batch_size=BATCH_SIZE,
    test_transform=test_transforms,
    dataset_name='APTOS_15_test',
    shrink_size=shrink_size)

# %%
# plot some of the images to check applied augmentations

IDRID_image_folder = "../IDRID/Imagenes/Imagenes" 
IDRID_csv_file = "../IDRID/idrid_labels.csv"  

test_dataset_with_transform = LoadDataset(IDRID_image_folder, IDRID_csv_file, transform=train_transforms)
test_dataset_no_transform = LoadDataset(IDRID_image_folder, IDRID_csv_file, transform=no_transforms)

for i in range(1):
    img_2 = test_dataset_with_transform[i][0].permute(1, 2, 0)
    img_1 = test_dataset_no_transform[i][0].permute(1, 2, 0)
    fig, axes = plt.subplots(1, 2)
    axes[0].imshow(img_1.numpy())
    axes[1].imshow(img_2.numpy())
    axes[0].axis(False)
    axes[1].axis(False)
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0665298..2.2489083].

# %%
model = OneHeadModel(device=device, p_dropout=p_dropout).to(device)

# %%
# Print a summary using torchinfo (uncomment for actual output)
torch.manual_seed(33)
summary(model=model, 
        input_size=(32, 3, 240, 240), # make sure this is "input_size", not "input_shape"
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# OneHeadModel (OneHeadModel)                   [32, 3, 240, 240]    [32, 5]              --                   True
# ├─Sequential (encoder)                        [32, 3, 240, 240]    [32, 1024, 7, 7]     --                   True
# │    └─Conv2d (conv0)                         [32, 3, 240, 240]    [32, 64, 120, 120]   9,408                True
# │    └─BatchNorm2d (norm0)                    [32, 64, 120, 120]   [32, 64, 120, 120]   128                  True
# │    └─ReLU (relu0)                           [32, 64, 120, 120]   [32, 64, 120, 120]   --                   --
# │    └─MaxPool2d (pool0)                      [32, 64, 120, 120]   [32, 64, 60, 60]     --                   --
# │    └─_DenseBlock (denseblock1)              [32, 64, 60, 60]     [32, 256, 60, 60]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [32, 64, 60, 60]     [32, 32, 60, 60]     45,440               True
# │    │    └─_DenseLayer (denselayer2)         [32, 64, 60, 60]     [32, 32, 60, 60]     49,600               True
# │    │    └─_DenseLayer (denselayer3)         [32, 64, 60, 60]     [32, 32, 60, 60]     53,760               True
# │    │    └─_DenseLayer (denselayer4)         [32, 64, 60, 60]     [32, 32, 60, 60]     57,920               True
# │    │    └─_DenseLayer (denselayer5)         [32, 64, 60, 60]     [32, 32, 60, 60]     62,080               True
# │    │    └─_DenseLayer (denselayer6)         [32, 64, 60, 60]     [32, 32, 60, 60]     66,240               True
# │    └─_Transition (transition1)              [32, 256, 60, 60]    [32, 128, 30, 30]    --                   True
# │    │    └─BatchNorm2d (norm)                [32, 256, 60, 60]    [32, 256, 60, 60]    512                  True
# │    │    └─ReLU (relu)                       [32, 256, 60, 60]    [32, 256, 60, 60]    --                   --
# │    │    └─Conv2d (conv)                     [32, 256, 60, 60]    [32, 128, 60, 60]    32,768               True
# │    │    └─AvgPool2d (pool)                  [32, 128, 60, 60]    [32, 128, 30, 30]    --                   --
# │    └─_DenseBlock (denseblock2)              [32, 128, 30, 30]    [32, 512, 30, 30]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [32, 128, 30, 30]    [32, 32, 30, 30]     53,760               True
# │    │    └─_DenseLayer (denselayer2)         [32, 128, 30, 30]    [32, 32, 30, 30]     57,920               True
# │    │    └─_DenseLayer (denselayer3)         [32, 128, 30, 30]    [32, 32, 30, 30]     62,080               True
# │    │    └─_DenseLayer (denselayer4)         [32, 128, 30, 30]    [32, 32, 30, 30]     66,240               True
# │    │    └─_DenseLayer (denselayer5)         [32, 128, 30, 30]    [32, 32, 30, 30]     70,400               True
# │    │    └─_DenseLayer (denselayer6)         [32, 128, 30, 30]    [32, 32, 30, 30]     74,560               True
# │    │    └─_DenseLayer (denselayer7)         [32, 128, 30, 30]    [32, 32, 30, 30]     78,720               True
# │    │    └─_DenseLayer (denselayer8)         [32, 128, 30, 30]    [32, 32, 30, 30]     82,880               True
# │    │    └─_DenseLayer (denselayer9)         [32, 128, 30, 30]    [32, 32, 30, 30]     87,040               True
# │    │    └─_DenseLayer (denselayer10)        [32, 128, 30, 30]    [32, 32, 30, 30]     91,200               True
# │    │    └─_DenseLayer (denselayer11)        [32, 128, 30, 30]    [32, 32, 30, 30]     95,360               True
# │    │    └─_DenseLayer (denselayer12)        [32, 128, 30, 30]    [32, 32, 30, 30]     99,520               True
# │    └─_Transition (transition2)              [32, 512, 30, 30]    [32, 256, 15, 15]    --                   True
# │    │    └─BatchNorm2d (norm)                [32, 512, 30, 30]    [32, 512, 30, 30]    1,024                True
# │    │    └─ReLU (relu)                       [32, 512, 30, 30]    [32, 512, 30, 30]    --                   --
# │    │    └─Conv2d (conv)                     [32, 512, 30, 30]    [32, 256, 30, 30]    131,072              True
# │    │    └─AvgPool2d (pool)                  [32, 256, 30, 30]    [32, 256, 15, 15]    --                   --
# │    └─_DenseBlock (denseblock3)              [32, 256, 15, 15]    [32, 1024, 15, 15]   --                   True
# │    │    └─_DenseLayer (denselayer1)         [32, 256, 15, 15]    [32, 32, 15, 15]     70,400               True
# │    │    └─_DenseLayer (denselayer2)         [32, 256, 15, 15]    [32, 32, 15, 15]     74,560               True
# │    │    └─_DenseLayer (denselayer3)         [32, 256, 15, 15]    [32, 32, 15, 15]     78,720               True
# │    │    └─_DenseLayer (denselayer4)         [32, 256, 15, 15]    [32, 32, 15, 15]     82,880               True
# │    │    └─_DenseLayer (denselayer5)         [32, 256, 15, 15]    [32, 32, 15, 15]     87,040               True
# │    │    └─_DenseLayer (denselayer6)         [32, 256, 15, 15]    [32, 32, 15, 15]     91,200               True
# │    │    └─_DenseLayer (denselayer7)         [32, 256, 15, 15]    [32, 32, 15, 15]     95,360               True
# │    │    └─_DenseLayer (denselayer8)         [32, 256, 15, 15]    [32, 32, 15, 15]     99,520               True
# │    │    └─_DenseLayer (denselayer9)         [32, 256, 15, 15]    [32, 32, 15, 15]     103,680              True
# │    │    └─_DenseLayer (denselayer10)        [32, 256, 15, 15]    [32, 32, 15, 15]     107,840              True
# │    │    └─_DenseLayer (denselayer11)        [32, 256, 15, 15]    [32, 32, 15, 15]     112,000              True
# │    │    └─_DenseLayer (denselayer12)        [32, 256, 15, 15]    [32, 32, 15, 15]     116,160              True
# │    │    └─_DenseLayer (denselayer13)        [32, 256, 15, 15]    [32, 32, 15, 15]     120,320              True
# │    │    └─_DenseLayer (denselayer14)        [32, 256, 15, 15]    [32, 32, 15, 15]     124,480              True
# │    │    └─_DenseLayer (denselayer15)        [32, 256, 15, 15]    [32, 32, 15, 15]     128,640              True
# │    │    └─_DenseLayer (denselayer16)        [32, 256, 15, 15]    [32, 32, 15, 15]     132,800              True
# │    │    └─_DenseLayer (denselayer17)        [32, 256, 15, 15]    [32, 32, 15, 15]     136,960              True
# │    │    └─_DenseLayer (denselayer18)        [32, 256, 15, 15]    [32, 32, 15, 15]     141,120              True
# │    │    └─_DenseLayer (denselayer19)        [32, 256, 15, 15]    [32, 32, 15, 15]     145,280              True
# │    │    └─_DenseLayer (denselayer20)        [32, 256, 15, 15]    [32, 32, 15, 15]     149,440              True
# │    │    └─_DenseLayer (denselayer21)        [32, 256, 15, 15]    [32, 32, 15, 15]     153,600              True
# │    │    └─_DenseLayer (denselayer22)        [32, 256, 15, 15]    [32, 32, 15, 15]     157,760              True
# │    │    └─_DenseLayer (denselayer23)        [32, 256, 15, 15]    [32, 32, 15, 15]     161,920              True
# │    │    └─_DenseLayer (denselayer24)        [32, 256, 15, 15]    [32, 32, 15, 15]     166,080              True
# │    └─_Transition (transition3)              [32, 1024, 15, 15]   [32, 512, 7, 7]      --                   True
# │    │    └─BatchNorm2d (norm)                [32, 1024, 15, 15]   [32, 1024, 15, 15]   2,048                True
# │    │    └─ReLU (relu)                       [32, 1024, 15, 15]   [32, 1024, 15, 15]   --                   --
# │    │    └─Conv2d (conv)                     [32, 1024, 15, 15]   [32, 512, 15, 15]    524,288              True
# │    │    └─AvgPool2d (pool)                  [32, 512, 15, 15]    [32, 512, 7, 7]      --                   --
# │    └─_DenseBlock (denseblock4)              [32, 512, 7, 7]      [32, 1024, 7, 7]     --                   True
# │    │    └─_DenseLayer (denselayer1)         [32, 512, 7, 7]      [32, 32, 7, 7]       103,680              True
# │    │    └─_DenseLayer (denselayer2)         [32, 512, 7, 7]      [32, 32, 7, 7]       107,840              True
# │    │    └─_DenseLayer (denselayer3)         [32, 512, 7, 7]      [32, 32, 7, 7]       112,000              True
# │    │    └─_DenseLayer (denselayer4)         [32, 512, 7, 7]      [32, 32, 7, 7]       116,160              True
# │    │    └─_DenseLayer (denselayer5)         [32, 512, 7, 7]      [32, 32, 7, 7]       120,320              True
# │    │    └─_DenseLayer (denselayer6)         [32, 512, 7, 7]      [32, 32, 7, 7]       124,480              True
# │    │    └─_DenseLayer (denselayer7)         [32, 512, 7, 7]      [32, 32, 7, 7]       128,640              True
# │    │    └─_DenseLayer (denselayer8)         [32, 512, 7, 7]      [32, 32, 7, 7]       132,800              True
# │    │    └─_DenseLayer (denselayer9)         [32, 512, 7, 7]      [32, 32, 7, 7]       136,960              True
# │    │    └─_DenseLayer (denselayer10)        [32, 512, 7, 7]      [32, 32, 7, 7]       141,120              True
# │    │    └─_DenseLayer (denselayer11)        [32, 512, 7, 7]      [32, 32, 7, 7]       145,280              True
# │    │    └─_DenseLayer (denselayer12)        [32, 512, 7, 7]      [32, 32, 7, 7]       149,440              True
# │    │    └─_DenseLayer (denselayer13)        [32, 512, 7, 7]      [32, 32, 7, 7]       153,600              True
# │    │    └─_DenseLayer (denselayer14)        [32, 512, 7, 7]      [32, 32, 7, 7]       157,760              True
# │    │    └─_DenseLayer (denselayer15)        [32, 512, 7, 7]      [32, 32, 7, 7]       161,920              True
# │    │    └─_DenseLayer (denselayer16)        [32, 512, 7, 7]      [32, 32, 7, 7]       166,080              True
# │    └─BatchNorm2d (norm5)                    [32, 1024, 7, 7]     [32, 1024, 7, 7]     2,048                True
# ├─AdaptiveAvgPool2d (global_avg_pool)         [32, 1024, 7, 7]     [32, 1024, 1, 1]     --                   --
# ├─Sequential (classification_head)            [32, 1024]           [32, 5]              --                   True
# │    └─Dropout (0)                            [32, 1024]           [32, 1024]           --                   --
# │    └─Linear (1)                             [32, 1024]           [32, 5]              5,125                True
# =============================================================================================================================
# Total params: 6,958,981
# Trainable params: 6,958,981
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 103.58
# =============================================================================================================================
# Input size (MB): 22.12
# Forward/backward pass size (MB): 6599.05
# Params size (MB): 27.84
# Estimated Total Size (MB): 6649.00
# =============================================================================================================================

# %% [markdown]
# Custom Focal Loss function

# %%
# class FocalLoss_custom(torch.nn.Module):
#     def __init__(self, alpha, gamma, headType=None):
#         super(FocalLoss_custom, self).__init__()
#         self.alpha = alpha.to(device)
#         self.gamma = gamma
#         self.headType = headType
#     def forward(self, inputs, targets):
        
#         ce_loss = F.cross_entropy(inputs, targets, reduction='none', label_smoothing=0.1)
#         # apply class weights
#         # alpha is for the weight class, weights is the correct weight for each class and looks like this: tensor([a, b, c, d, a, ...])
#         weights = self.alpha.gather(0, targets)

#         pt = torch.exp(-ce_loss)
#         loss = (weights * ((1 - pt) ** self.gamma) * ce_loss)
#         # loss = (self.alpha * ((1 - pt) ** self.gamma) * ce_loss)
#         return loss.mean()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2, label_smoothing=0):
        super(FocalLoss, self).__init__()
        self.alpha = alpha.to(device)
        self.gamma = gamma
        self.label_smoothing = label_smoothing

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none', label_smoothing=self.label_smoothing)
        pt = torch.exp(-ce_loss)
        loss = (self.alpha[targets] * (1 - pt) ** self.gamma * ce_loss).mean()
        return loss

# %%
# Define loss and optimizer

# from going_modular.focal_loss import FocalLoss

# weights are selected based on the APTOS 2019 distribution according to the paper
# weight = torch.tensor([3260/1750, 3260/270, 3260/840, 3260/140, 3260/260]) * 0.1
# weight = torch.tensor([1/1805, 1/370, 1/999, 1/193, 1/295]) * 500 

# weights.to(device)

loss_fn_classification = nn.BCEWithLogitsLoss().to(device)

# loss_fn_classification = nn.CrossEntropyLoss().to(device)
# loss_fn_classification = nn.CrossEntropyLoss(weight=weight).to(device)
# loss_fn_classification = FocalLoss_custom(headType='classification', alpha=alpha, gamma=gamma).to(device)
# loss_fn_classification = FocalLoss(alpha=alpha, gamma=gamma, label_smoothing=label_smoothing).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_deacay)

# scheduler = CosineAnnealingLR(optimizer, T_max=T_max, eta_min=eta_min)

from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5)

# %%
# model = torch.compile(model)

if allow_train:
    # Set the random seeds
    torch.manual_seed(1404)
    torch.cuda.manual_seed(1404)

    # Start the timer
    from timeit import default_timer as timer 
    start_time = timer()

    # Setup training and save the results

    train_results, val_results = engine.train(model=model,
                train_dataloader=train_dataloader,
                val_dataloader=val_dataloader,
                optimizer=optimizer,
                scheduler=scheduler,
                loss_fn_classification=loss_fn_classification,
                epochs=EPOCHS,
                device=device)
    
    helper_functions.plot_t_SNE(model=model,
                            dataloader=val_dataloader,
                            NUM_ITER=2000)
    
    utils.save_model(model=model, target_dir='models', model_name=f'main_train_model.pth')


    # End the timer and print out how long it took
    end_time = timer()
    print(f"[INFO] Total training time: {end_time-start_time:.3f} seconds")
else:
    model.load_state_dict(torch.load('models/main_train_model.pth', weights_only=True, map_location=device))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 14
#      10 start_time = timer()
#      12 # Setup training and save the results
# ---> 14 train_results, val_results = engine.train(model=model,
#      15             train_dataloader=train_dataloader,
#      16             val_dataloader=val_dataloader,
#      17             optimizer=optimizer,
#      18             scheduler=scheduler,
#      19             loss_fn_classification=loss_fn_classification,
#      20             epochs=EPOCHS,
#      21             device=device)
#      23 helper_functions.plot_t_SNE(model=model,
#      24                         dataloader=val_dataloader,
#      25                         NUM_ITER=2000)
#      27 utils.save_model(model=model, target_dir='models', model_name=f'main_train_model.pth')
#
# File d:\University Project\DR_Project_Kaggle1\going_modular\engine.py:176, in train(model, train_dataloader, val_dataloader, optimizer, scheduler, loss_fn_classification, epochs, device)
#     174 # Loop through training and testing steps for a number of epochs
#     175 for epoch in tqdm(range(1, epochs+1)):
# --> 176     loss_classification_train, acc_classification_train = train_step(
#     177         model=model,
#     178         dataloader=train_dataloader,
#     179         loss_fn_classification=loss_fn_classification,
#     180         optimizer=optimizer,
#     181         device=device)
#     183     loss_classification_val, acc_classification_val = val_step(
#     184         model=model,
#     185         dataloader=val_dataloader,
#     186         loss_fn_classification=loss_fn_classification,
#     187         device=device)
#     189     # scheduler.step()
#
# File d:\University Project\DR_Project_Kaggle1\going_modular\engine.py:57, in train_step(model, dataloader, loss_fn_classification, optimizer, device)
#      53 with torch.autocast(device_type=device, enabled=True):
#      55     class_out, enc_out= model(X)
# ---> 57     loss_classification = loss_fn_classification(class_out, y_cumulative)
#      59 scalar.scale(loss_classification).backward()
#      60 scalar.step(optimizer)
#
# File c:\Users\Amiroodi\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Amiroodi\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File c:\Users\Amiroodi\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\loss.py:734, in BCEWithLogitsLoss.forward(self, input, target)
#     733 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 734     return F.binary_cross_entropy_with_logits(input, target,
#     735                                               self.weight,
#     736                                               pos_weight=self.pos_weight,
#     737                                               reduction=self.reduction)
#
# File c:\Users\Amiroodi\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\functional.py:3242, in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3239     reduction_enum = _Reduction.get_enum(reduction)
#    3241 if not (target.size() == input.size()):
# -> 3242     raise ValueError(f"Target size ({target.size()}) must be the same as input size ({input.size()})")
#    3244 return torch.binary_cross_entropy_with_logits(input, target, weight, pos_weight, reduction_enum)
#
# ValueError: Target size (torch.Size([32, 4])) must be the same as input size (torch.Size([32, 5]))

# %%
if allow_train:
    helper_functions.plot_loss_curves(train_results, val_results)
    helper_functions.plot_acc_curves(train_results, val_results)

# %%
test_results = engine.test_step(model=model,
            dataloader=test_dataloader,
            device=device)

# %%
test_results = engine.test_step(model=model,
            dataloader=exp_train_dataloader,
            device=device)

# %%
MESSIDOR_test_results = engine.test_step(model=model,
            dataloader=MESSIDOR_dataloader,
            device=device)

# %%
IDRID_test_results = engine.test_step(model=model,
            dataloader=IDRID_dataloader,
            device=device)

# %%
APTOS_15_test_results = engine.test_step(model=model,
            dataloader=APTOS_15_test_dataloader,
            device=device)

# %%
helper_functions.plot_t_SNE(model=model,
                        dataloader=test_dataloader,
                        perp_vals=[5, 40],
                        NUM_ITER=2000)
